# %% [markdown]
# # Oppgave 2 - Klassifikasjon (30%)<a name="oppgave2"></a>

# %% [markdown]
# *Oppgave 2 består av 4 deler med til sammen 15 spørsmål, der alle spørsmål (2a.1), 2a.2) etc.) teller likt. Oppgave 2 teller totalt 30 % av prosjektet.*
#
# **Oppgaven inneholder følgende elementer:**
#
# * Laste inn og utforske et datasett for klassifikasjon
# * Dele datasettet inn i treningssett, valideringssett og testsett
# * Tilpasse en logistisk regresjon og bruke denne til å klassifisere
# * Utføre $k$-nærmeste nabo-klassifikasjon
# * Evaluere godhet av klassifikasjonsresultatene
#
# ## Innholdsfortegnelse
# * [Ble det hjemmeseier?](#intro)
# * [Oppgave 2a) Lese inn og preprosessere data](#oppgave2a)
# * [Oppgave 2b) Logistisk regresjon](#oppgave2b)
# * [Oppgave 2c) $k$-nærmeste-nabo-klassifikasjon](#oppgave2c)
# * [Oppgave 2d) Evaluere beste modeller](#oppgave2d)

# %% [markdown]
# ### Ble det hjemmeseier?<a name="intro"></a>
#
# Datasettet vi skal se på er fra de fire øverste divisjonene i engelsk fotball, i sesongen 2022-2023, og oppgaven går ut på å tilpasse ulike metoder for å predikere om hjemmelaget vinner en gitt kamp utifra data på antall skudd på mål, cornere og forseelser (regelbrudd som fører til frispark eller straffespark).
#
# Mer informasjon om dataene: https://www.football-data.co.uk/englandm.php.

# %%
# %pip install numpy
# %pip install pandas
# %pip install matplotlib
# %pip install seaborn
# %pip install statsmodels
# %pip install scikit-learn
# %pip install Jinja2
# Out:
# Requirement already satisfied: numpy in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (1.26.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (2.1.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from pandas) (1.26.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from matplotlib) (1.26.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (0.13.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from seaborn) (1.26.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from seaborn) (2.1.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from seaborn) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: statsmodels in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (0.14.0)
# Requirement already satisfied: numpy>=1.18 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from statsmodels) (1.26.1)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from statsmodels) (1.11.3)
# Requirement already satisfied: pandas>=1.0 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from statsmodels) (2.1.1)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from statsmodels) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from pandas>=1.0->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from pandas>=1.0->statsmodels) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from pandas>=1.0->statsmodels) (2023.3)
# Requirement already satisfied: six in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from scikit-learn) (1.26.1)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from scikit-learn) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: Jinja2 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (3.1.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\vikto\anaconda3\envs\venv\lib\site-packages (from Jinja2) (2.1.3)

# %%
# importere pakker og funksjoner vi trenger i oppgave 2
import numpy as np
import pandas as pd
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import seaborn as sns
from scipy import stats
import statsmodels.formula.api as smf
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ### Oppgave 2a) Lese inn og preprosessere data<a name="oppgave2a"></a>
#
# *Oppgave 2a) inneholder 5 spørsmål du skal svare på.*
#
# Datasettet vi skal jobbe med inneholder informasjon om fotballkamper i engelsk fotball. Dataene finnes i fire forskjellige filer, og hver fil inneholder informasjon om kampene i en gitt divisjon. Vi laster inn dataene fra hver fil og kombinerer dem. Etter vi har gjort dette har datasettet $2036$ rader og $106$ kolonner. En gitt rad tilsvarer en gitt kamp og en gitt kolonne tilsvarer en type informasjon (f.eks. antall cornere hjemmelaget hadde). Kolonner som begynner på `H` angår hjemmelaget og `A` angår bortelaget.
#
# I en gitt kamp vinner enten hjemmelaget, eller så vinner ikke hjemmelaget (uavgjort eller borteseier). Resultatet av en kamp er dermed at:
# * hjemmelaget vinner - kodet som $1$
# * hjemmelaget vinner ikke - kodet som $0$.
#
# Kampresultatet ($0$ eller $1$) legger vi i kolonnen `y`, som skal være hva vi vil predikere/klassifisere.
#
# Vi skal ikke se på alle variablene i datasettet, og skal i tillegg til `y` konsentrere oss om kolonnene
#
# * `HST`, `AST`: antall skudd på mål for henholdsvis hjemmelaget og bortelaget
# * `HC`, `AC`: antall cornere for henholdsvis hjemmelaget og bortelaget
# * `HF`, `AF`: antall forseelser for henholdsvis hjemmelaget og bortelaget
#
# Istedenfor å se direkte på disse tre antallene for de to lagene, ser vi heller på *differansene* for hver kamp. Vi lager de nye variablene
#
# * `skudd_paa_maal_diff`=`HST`-`AST`
# * `corner_diff`=`HC`-`AC`
# * `forseelse_diff`=`HF`-`AF`
#
# og dette skal være forklaringsvariablene våre.
#
# _Oppsummert_: Observasjonsenheten i dataene er en fotballkamp, vi har tre forklaringsvariabler `skudd_paa_maal_diff`, `corner_diff` og `forseelse_diff`, mens `y` (0 eller 1) er responsen vi ønsker å predikere.
#
#
# Koden under leser inn dataene, lager de nye variablene og putter alt inn i en ny data frame. Etter det er gjort har vi en datasett med $2036$ rader (kamper) og $4$ kolonner (variabler).

# %%
# Lese inn datasettene ved funksjon fra pandas (df=data frame - vanlig navn å gi et datasett)
df0 = pd.read_csv("https://www.math.ntnu.no/emner/IST100x/ISTx1003/h2023/E0.csv", sep = ',') # Premier League
df1 = pd.read_csv("https://www.math.ntnu.no/emner/IST100x/ISTx1003/h2023/E1.csv", sep = ',') # Championship
df2 = pd.read_csv("https://www.math.ntnu.no/emner/IST100x/ISTx1003/h2023/E2.csv", sep = ',') # League 1
df3 = pd.read_csv("https://www.math.ntnu.no/emner/IST100x/ISTx1003/h2023/E3.csv", sep = ',') # League 2

print(str(len(df0)))
print(str(len(df1)))
print(str(len(df2)))
print(str(len(df3)))

# Sett sammen datasettene til 1 data-frame
df_in=pd.concat([df0,
                 df1,
                 df2,
                 df3], ignore_index = True)
df=pd.concat([pd.Series(np.where(df_in['FTR'] == 'H', 1, 0)),
              df_in['HST']-df_in['AST'], 
              df_in['HC']-df_in['AC'],
              df_in['HF']-df_in['AF']], axis = 1)

# Henter ut de dataene vi er interessert i
df.columns=['y', 'skudd_paa_maal_diff', 'corner_diff', 'forseelse_diff']
print(df.describe())
# Out:
# 380
# 552
# 552
# 552
#                  y  skudd_paa_maal_diff  corner_diff  forseelse_diff
# count  2036.000000          2036.000000  2036.000000     2036.000000
# mean      0.432711             0.797151     1.003438       -0.549607
# std       0.495573             3.324189     4.347722        4.583058
# min       0.000000           -11.000000   -17.000000      -17.000000
# 25%       0.000000            -1.000000    -2.000000       -4.000000
# 50%       0.000000             1.000000     1.000000        0.000000
# 75%       1.000000             3.000000     4.000000        2.000000
# max       1.000000            12.000000    16.000000       17.000000

# %% [markdown]
# Videre vil vi dele datasettet vårt inn i tre datasett: et treningssett, et valideringssett og et testsett. Først deler vi data inn i 80\% trening/validering og 20\% test, og deretter deler vi trening/valideringssettet inn i 75\% trening og 25\% validering.

# %%
df_trenval, df_test = train_test_split(df, test_size = 0.2, random_state = 1, stratify = df['y'])
df_tren, df_val = train_test_split(df_trenval, test_size = 0.25, random_state = 1, stratify = df_trenval['y'])
print("treningssett: \n", df_tren.shape)
print(df_tren.describe())
print(df_tren["y"].value_counts())
print("\nvalideringssett: \n", df_val.shape)
print(df_val.describe())
print(df_val["y"].value_counts())
print("\ntestsett: \n", df_test.shape)
print(df_test.describe())
print(df_test["y"].value_counts())
# Out:
# treningssett:
#  (1221, 4)
#                  y  skudd_paa_maal_diff  corner_diff  forseelse_diff
# count  1221.000000          1221.000000  1221.000000     1221.000000
# mean      0.432432             0.933661     1.020475       -0.701065
# std       0.495617             3.286039     4.331025        4.601308
# min       0.000000           -11.000000   -17.000000      -17.000000
# 25%       0.000000            -1.000000    -2.000000       -4.000000
# 50%       0.000000             1.000000     1.000000       -1.000000
# 75%       1.000000             3.000000     4.000000        2.000000
# max       1.000000            12.000000    14.000000       17.000000
# y
# 0    693
# 1    528
# Name: count, dtype: int64
#
# valideringssett:
#  (407, 4)
#                 y  skudd_paa_maal_diff  corner_diff  forseelse_diff
# count  407.000000           407.000000   407.000000      407.000000
# mean     0.432432             0.734644     1.002457       -0.324324
# std      0.496023             3.345956     4.333112        4.589877
# min      0.000000           -10.000000   -12.000000      -16.000000
# 25%      0.000000            -2.000000    -2.000000       -3.000000
# 50%      0.000000             1.000000     1.000000        0.000000
# 75%      1.000000             3.000000     4.000000        3.000000
# max      1.000000            11.000000    16.000000       17.000000
# y
# 0    231
# 1    176
# Name: count, dtype: int64
#
# testsett:
#  (408, 4)
#                 y  skudd_paa_maal_diff  corner_diff  forseelse_diff
# count  408.000000           408.000000   408.000000      408.000000
# mean     0.433824             0.450980     0.953431       -0.321078
# std      0.496210             3.396421     4.421890        4.513409
# min      0.000000            -9.000000   -12.000000      -13.000000
# 25%      0.000000            -2.000000    -2.000000       -4.000000
# 50%      0.000000             1.000000     1.000000        0.000000
# 75%      1.000000             3.000000     4.000000        3.000000
# max      1.000000            12.000000    15.000000       13.000000
# y
# 0    231
# 1    177
# Name: count, dtype: int64

# %% [markdown]
# I denne oppgaven skal vi etterhvert tilpasse logistisk regresjon og $k$-nærmeste nabo-klassifikasjon.
#
# **2a.1)** Hvorfor ønsker vi å dele dataene inn i trening-, validering- og test-sett?
#
# **2a.2)** Hvor stor andel av dataene er nå i hver av de tre settene? Ser de tre datasettene ut til å ha lik fordeling for de tre forklaringsvariablene og responsen?
#
# **2a.3)** La oss si at vi hadde valgt League 1 og 2 som treningssett, Championship som valideringssett, og Premier League som testsett. Hvorfor hadde dette vært dumt?
#
# For å utforske dataene lager vi kryssplott av de tre forklaringsvariablene for treningsdataene og fargelegger punktene fra kampene etter hvorvidt det var hjemmeseier eller ikke. På diagonalen ser vi empiriske tetthetsplott (glattet variant av et histogram). Under har vi også regnet ut empirisk korrelasjonskoeffisient for alle par av variabler.

# %%
#2a.1
print("1. Å holde testsettet uavhengig av trening- og valideringssettet hjelper med å forhindre \nat informasjon lekker fra testsettet til treningsprosessen, som kan føre til overoptimistiske resultater. \n")

#2a.2
print("Fordeling er 60% treningssett, 20% valideringssett og 20% testsett")

#2a.3
print("\nUlikt spiller nivå i ligaenene. Dette kan føre til at dataene fra disse ligaene kan være forskjellige når det gjelder spillestil," + 
      "taktikk, og spillernes ferdigheter. \nHvis du trener en modell på lavere nivå data og deretter prøver å bruke den på Premier League-data,"+ 
      "kan den gi upålitelige resultater på grunn av disse forskjellene.")
print("De underliggende stokastiske prosessene i de forskjellige ligaene er ikke nødvendigvis like, det vil si at man trener på en stokastisk prosess \n" + 
      "og deretter prøve å predikere en annen stokastisk prosess med denne modellen")
# Out:
# 1. Å holde testsettet uavhengig av trening- og valideringssettet hjelper med å forhindre
# at informasjon lekker fra testsettet til treningsprosessen, som kan føre til overoptimistiske resultater.
#
# Fordeling er 60% treningssett, 20% valideringssett og 20% testsett
#
# Ulikt spiller nivå i ligaenene. Dette kan føre til at dataene fra disse ligaene kan være forskjellige når det gjelder spillestil,taktikk, og spillernes ferdigheter.
# Hvis du trener en modell på lavere nivå data og deretter prøver å bruke den på Premier League-data,kan den gi upålitelige resultater på grunn av disse forskjellene.
# De underliggende stokastiske prosessene i de forskjellige ligaene er ikke nødvendigvis like, det vil si at man trener på en stokastisk prosess
# og deretter prøve å predikere en annen stokastisk prosess med denne modellen

# %%
sns.pairplot(df_tren, vars = ['skudd_paa_maal_diff','corner_diff','forseelse_diff'],
             hue = 'y', 
             diag_kind = 'kde',
             plot_kws = dict(alpha = 0.4))
plt.show()

# %%
corr = df_tren.corr()
display(corr.style.background_gradient(cmap = 'coolwarm', axis = None, vmin = -1, vmax = 1))
plt.show()
# Out:
# <style type="text/css">
# #T_ca609_row0_col0, #T_ca609_row1_col1, #T_ca609_row2_col2, #T_ca609_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ca609_row0_col1, #T_ca609_row1_col0 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_ca609_row0_col2, #T_ca609_row2_col0 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_ca609_row0_col3, #T_ca609_row3_col0 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_ca609_row1_col2, #T_ca609_row2_col1 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_ca609_row1_col3, #T_ca609_row3_col1 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_ca609_row2_col3, #T_ca609_row3_col2 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# </style>
# <table id="T_ca609">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ca609_level0_col0" class="col_heading level0 col0" >y</th>
#       <th id="T_ca609_level0_col1" class="col_heading level0 col1" >skudd_paa_maal_diff</th>
#       <th id="T_ca609_level0_col2" class="col_heading level0 col2" >corner_diff</th>
#       <th id="T_ca609_level0_col3" class="col_heading level0 col3" >forseelse_diff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ca609_level0_row0" class="row_heading level0 row0" >y</th>
#       <td id="T_ca609_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_ca609_row0_col1" class="data row0 col1" >0.423284</td>
#       <td id="T_ca609_row0_col2" class="data row0 col2" >-0.004892</td>
#       <td id="T_ca609_row0_col3" class="data row0 col3" >0.007606</td>
#     </tr>
#     <tr>
#       <th id="T_ca609_level0_row1" class="row_heading level0 row1" >skudd_paa_maal_diff</th>
#       <td id="T_ca609_row1_col0" class="data row1 col0" >0.423284</td>
#       <td id="T_ca609_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_ca609_row1_col2" class="data row1 col2" >0.343355</td>
#       <td id="T_ca609_row1_col3" class="data row1 col3" >-0.051163</td>
#     </tr>
#     <tr>
#       <th id="T_ca609_level0_row2" class="row_heading level0 row2" >corner_diff</th>
#       <td id="T_ca609_row2_col0" class="data row2 col0" >-0.004892</td>
#       <td id="T_ca609_row2_col1" class="data row2 col1" >0.343355</td>
#       <td id="T_ca609_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_ca609_row2_col3" class="data row2 col3" >-0.055752</td>
#     </tr>
#     <tr>
#       <th id="T_ca609_level0_row3" class="row_heading level0 row3" >forseelse_diff</th>
#       <td id="T_ca609_row3_col0" class="data row3 col0" >0.007606</td>
#       <td id="T_ca609_row3_col1" class="data row3 col1" >-0.051163</td>
#       <td id="T_ca609_row3_col2" class="data row3 col2" >-0.055752</td>
#       <td id="T_ca609_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **2a.4)** Kommenter kort på hva du ser i plottene og utskriften (maks 5 setninger).
#
# **2a.5)** Hvilke(n) av de tre variablene tror du vil være god(e) til å bruke til å predikere om det blir hjemmeseier? Begrunn svaret kort (maks 3 setninger).

# %%
#2a.4
print("Scatter plottet viser hvor mye sammenheng det er mellom de forskjellige variablene hvor fargen avgjør om det er seier eller ikke, og hvis vi ser tydlig farge mønster vil det være påviklning av variabelen mellom seier og tap for hjemmlaget." )
print("For eksempel ser vi at høy corner diff samtidig som høy skudd på mål diff har flere hjemme seiere siden denne delen av scatter plottet er mer orange.")
print("Derimot ser vi at det er ingen fargenyanser i plottet corner diff og forseelse diff, og dette betyr at disse ikke påvirker seier i den ene eller andre rettningen")
print("Diagonalen viser et enkelt histogram plot for hver av variablene et histogram for y = 1 og y = 0 i forskjellig farge")
print("Utskriften viser korrelasjonsmatrisen mellom de 3 varablene")
print("")

#2a.5
print("Korrelasjons matrisen viser at det kun er skudd_paa_maal_diff som er positivt korrelert med hjemmelagets seier (y = 1). \nDe øvrige varablene viser lite korrelasjon med y. Derimot er det interasant å merke seg at skudd på mål er korrelert med corner")
# Out:
# Scatter plottet viser hvor mye sammenheng det er mellom de forskjellige variablene hvor fargen avgjør om det er seier eller ikke, og hvis vi ser tydlig farge mønster vil det være påviklning av variabelen mellom seier og tap for hjemmlaget.
# For eksempel ser vi at høy corner diff samtidig som høy skudd på mål diff har flere hjemme seiere siden denne delen av scatter plottet er mer orange.
# Derimot ser vi at det er ingen fargenyanser i plottet corner diff og forseelse diff, og dette betyr at disse ikke påvirker seier i den ene eller andre rettningen
# Diagonalen viser et enkelt histogram plot for hver av variablene et histogram for y = 1 og y = 0 i forskjellig farge
# Utskriften viser korrelasjonsmatrisen mellom de 3 varablene
#
# Korrelasjons matrisen viser at det kun er skudd_paa_maal_diff som er positivt korrelert med hjemmelagets seier (y = 1).
# De øvrige varablene viser lite korrelasjon med y. Derimot er det interasant å merke seg at skudd på mål er korrelert med corner

# %% [markdown]
# ### Oppgave 2b) Logistisk regresjon<a name="oppgave2b"></a>
#
# *Oppgave 2b) inneholder 5 spørsmål du skal svare på.*
#
# Vi tilpasser en logistisk regresjon til treningssettet, og regner ut feilrate for valideringssettet gitt at vi klassifiserer som suksess (hjemmeseier) når sannsynligheten for hjemmeseier er anslått til minst 0.5.
#
# Dette gjør vi med de samme stegene som det vi gjorde for multippel lineær regresjon:
#
# 1) Bli kjent med dataene ved å se på oppsummeringsmål og ulike typer plott
# 2) Spesifisere en matematisk modell (modellformel)
# 3) Initialisere og tilpasse modellen
# 4) Presentere resultater fra den tilpassede modellen
# 5) Evaluere om modellen passer til dataene
#
# Vi er ferdige med Steg 1, og gjør så Steg 2-4 under.

# %%
# Steg 2: Modellformel
formel = "y ~ skudd_paa_maal_diff + corner_diff + forseelse_diff"

# Steg 3: Initialiser modellen 
modell = smf.logit(formel, data = df_tren)

# Tilpass modellen
resultat = modell.fit()

# Steg 4: Presenter koeffisient-verdier (betaer) fra den tilpassede modellen 
print("\nKoeffisentverdier:\n\n", resultat.params)

print(resultat.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.567874
#          Iterations 6
#
# Koeffisentverdier:
#
#  Intercept             -0.591661
# skudd_paa_maal_diff    0.382565
# corner_diff           -0.100377
# forseelse_diff         0.012009
# dtype: float64
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1221
# Model:                          Logit   Df Residuals:                     1217
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 31 Oct 2023   Pseudo R-squ.:                  0.1698
# Time:                        14:16:38   Log-Likelihood:                -693.37
# converged:                       True   LL-Null:                       -835.15
# Covariance Type:            nonrobust   LLR p-value:                 3.607e-61
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              -0.5917      0.072     -8.190      0.000      -0.733      -0.450
# skudd_paa_maal_diff     0.3826      0.027     14.203      0.000       0.330       0.435
# corner_diff            -0.1004      0.017     -6.069      0.000      -0.133      -0.068
# forseelse_diff          0.0120      0.014      0.848      0.396      -0.016       0.040
# =======================================================================================

# %% [markdown]
# **2b.1)** I en kamp der `skudd_paa_maal_diff` er $2$, `corner_diff` er $-2$ og `forseelse_diff` er $6$, hva er ifølge modellen sannsynligheten for at hjemmelaget vinner? Vis utregninger og/eller kode, og oppgi svaret med tre desimaler.
#
# **2b.2)** Hvordan kan du tolke verdien av $e^{\beta_{\texttt{skudd_paa_maal_diff}}}$?

# %%
#2b.1
skudd_paa_maal_diff = 2
corner_diff = -2
forseelse_diff = 6

intercept = resultat.params["Intercept"]
coef_skudd_paa_maal_diff = resultat.params["skudd_paa_maal_diff"]
coef_corner_diff = resultat.params["corner_diff"]
coef_forseelse_diff = resultat.params["forseelse_diff"]

log_odds = intercept + coef_skudd_paa_maal_diff * skudd_paa_maal_diff + coef_corner_diff * corner_diff + coef_forseelse_diff * forseelse_diff

import math
probability = 1 / (1 + math.exp(-log_odds))

predicted_class = 1 if probability > 0.5 else 0

print("Predicted Probability:", probability)
print("Predicted Class:", predicted_class)


#2b.2
print("\n$e^{\beta_{\texttt{skudd_paa_maal_diff}}}$ erd eksponenten til denne koeffisienten.")
print("Denne verdien gir en indikasjon på hvor mye multiplikativ effekt en enhets endring i 'skudd_paa_maal_diff' har på oddsen for en positiv utfall (for eksempel 'y = 1').")
print("$e^{\beta_{\texttt{skudd_paa_maal_diff}}}$ = 1 (Ingen endring i oddsen)")
print("$e^{\beta_{\texttt{skudd_paa_maal_diff}}}$ < 1 (Økning i oddsen for positivt utfall)")
print("$e^{\beta_{\texttt{skudd_paa_maal_diff}}}$ > 1 (Minking i oddsen for positivt utfall)")
# Out:
# Predicted Probability: 0.6097534665532253
# Predicted Class: 1
#
# $e^eta_{	exttt{skudd_paa_maal_diff}}}$ erd eksponenten til denne koeffisienten.
# Denne verdien gir en indikasjon på hvor mye multiplikativ effekt en enhets endring i 'skudd_paa_maal_diff' har på oddsen for en positiv utfall (for eksempel 'y = 1').
# $e^eta_{	exttt{skudd_paa_maal_diff}}}$ = 1 (Ingen endring i oddsen)
# $e^eta_{	exttt{skudd_paa_maal_diff}}}$ < 1 (Økning i oddsen for positivt utfall)
# $e^eta_{	exttt{skudd_paa_maal_diff}}}$ > 1 (Minking i oddsen for positivt utfall)

# %% [markdown]
# **2b.3)** Hva angir feilraten til modellen? Hvilket datasett er feilraten regnet ut fra? Er du fornøyd med verdien til feilraten?

# %%
# Spesifiser verdi for cutoff
cutoff = 0.5

# Prediker verdi for valideringssettet
val_pred = resultat.predict(exog = df_val)

# Klassifiser som seier for hjemmelaget hvis sannsynligheten for at hjemmelaget vant er over 0.5
y_valpred = np.where(val_pred > cutoff, 1, 0)
y_valobs = df_val['y']

# Finn feilrate
print("Feilrate:", 1 - accuracy_score(y_true = y_valobs, y_pred = y_valpred))
# Out:
# Feilrate: 0.28501228501228504

# %%
#2b.3
print("Feilraten til modellen angir andelen feil klassifiserte observasjoner i forhold til det totale antallet observasjoner i valideringsdatasettet. \nDen måler hvor godt modellen presterer i å korrekt klassifisere data.")
print("\nFeilraten er regnet utifra valideringsdatasettet")
print("\nÅ ha en feilrate på 0.28 er solid for å predikere en seier for et hjemmelag")
# Out:
# Feilraten til modellen angir andelen feil klassifiserte observasjoner i forhold til det totale antallet observasjoner i valideringsdatasettet.
# Den måler hvor godt modellen presterer i å korrekt klassifisere data.
#
# Feilraten er regnet utifra valideringsdatasettet
#
# Å ha en feilrate på 0.28 er solid for å predikere en seier for et hjemmelag

# %% [markdown]
# Tilpass nå den logistiske regresjonen uten `forseelse_diff` som forklaringsvariabel - ved å kopiere koden over (men ikke den gamle formelen).
#
# **2b.4)** Diskuter kort hvordan koeffisientene ($\beta$-ene) og feilraten endrer seg når `forseelse_diff` tas ut av modellen (maks 3 setninger).
#
# **2b.5)** Med den nye modellen: I en kamp der `skudd_paa_maal_diff` $= 2$, `corner_diff` $= -2$ og `forseelse_diff` $= 6$, hva er sannsynligheten for at hjemmelaget vinner ifølge den nye modellen? Oppgi svaret med tre desimaler.
#
# **2b.6)** Hvis du skal finne en så god som mulig klassifikasjonsmodell med logistisk regresjon, vil du velge modellen med eller uten `forseelse_diff` som forklaringsvariabel? Begrunn kort svaret (maks 3 setninger).

# %%
# her kan du lime inn kode for å svare på 2b.4) til 2b.6)
# Steg 2: Modellformel
formel = "y ~ skudd_paa_maal_diff + corner_diff"

# Steg 3: Initialiser modellen 
modell = smf.logit(formel, data = df_tren)

# Tilpass modellen
resultat1 = modell.fit()

# Steg 4: Presenter koeffisient-verdier (betaer) fra den tilpassede modellen 
print("\nKoeffisentverdier:\n\n", resultat1.params)
print("\n")

skudd_paa_maal_diff = 2
corner_diff = -2
forseelse_diff = 6

intercept = resultat1.params["Intercept"]
coef_skudd_paa_maal_diff = resultat1.params["skudd_paa_maal_diff"]
coef_corner_diff = resultat1.params["corner_diff"]

log_odds = intercept + coef_skudd_paa_maal_diff * skudd_paa_maal_diff + coef_corner_diff * corner_diff

import math
probability = 1 / (1 + math.exp(-log_odds))

predicted_class = 1 if probability > 0.5 else 0

print("Predicted Probability:", probability)
print("Predicted Class:", predicted_class)

#3b.4
print("\n\nVi så i forrige oppgave at koffesienten til forseelese_diff var posiiv. \nKoffesienten var ikke stor, men den vil fortsatt føre til en økning i oddsen for positivt utfall for hjemmelaget.\ Når man fjerner denne variablen vil det pårvike de gjenværende koeffesientene\n")

#3b.5
print("Sansynligheten: ", probability)

#3b.6
print("Korrelasjonen er lav for seier, som vil si at den har liten betydning i oddsen.")

print("Dersom vi henter ut z verdien til forseelse_diff i orginal modellen (resultat.summary()) ser vi at den er på 0.396 og signifikans nivået på 0.95 er derfor ikke oppfyllt.")  

print("Vi velger derfor å velge bort variabelen i modellen")
# Out:
# Optimization terminated successfully.
#          Current function value: 0.568168
#          Iterations 6
#
# Koeffisentverdier:
#
#  Intercept             -0.598601
# skudd_paa_maal_diff    0.381953
# corner_diff           -0.101081
# dtype: float64
#
#
# Predicted Probability: 0.5908469115899905
# Predicted Class: 1
#
#
# Vi så i forrige oppgave at koffesienten til forseelese_diff var posiiv.
# Koffesienten var ikke stor, men den vil fortsatt føre til en økning i oddsen for positivt utfall for hjemmelaget.\ Når man fjerner denne variablen vil det pårvike de gjenværende koeffesientene
#
# Sansynligheten:  0.5908469115899905
# Korrelasjonen er lav for seier, som vil si at den har liten betydning i oddsen.
# Dersom vi henter ut z verdien til forseelse_diff i orginal modellen (resultat.summary()) ser vi at den er på 0.396 og signifikans nivået på 0.95 er derfor ikke oppfyllt.
# Vi velger derfor å velge bort variabelen i modellen
# <>:34: SyntaxWarning: invalid escape sequence '\ '
# <>:34: SyntaxWarning: invalid escape sequence '\ '
# C:\Users\vikto\AppData\Local\Temp\ipykernel_27928\328419961.py:34: SyntaxWarning: invalid escape sequence '\ '
#   print("\n\nVi så i forrige oppgave at koffesienten til forseelese_diff var posiiv. \nKoffesienten var ikke stor, men den vil fortsatt føre til en økning i oddsen for positivt utfall for hjemmelaget.\ Når man fjerner denne variablen vil det pårvike de gjenværende koeffesientene\n")

# %% [markdown]
# ### Oppgave 2c) $k$-nærmeste-nabo-klassifikasjon<a name="oppgave2c"></a>
#
# *Oppgave 2c) inneholder 2 spørsmål du skal svare på.*
#
# Vi skal nå kun se på forklaringsvariablene `skudd_paa_maal_diff` og `corner_diff`, og tilpasse $k$-nærmeste-nabo-metoden der vi bruker euklidsk avstand som avstandsmål. Vi bruker valideringssettet til å velge $k$.
#
# Koden under tilpasser $k$-nærmeste nabo-klassifikasjon for ulike verdier for $k$, deretter regnes feilrate ut på valideringssettet og plottes.

# %%
knaboer = np.arange(1, 251, step = 2)
val_feilrate = np.empty(len(knaboer))

X_tren = df_tren[['skudd_paa_maal_diff', 'corner_diff']] # bruker bare disse to forklaringsvariablene
X_val = df_val[['skudd_paa_maal_diff', 'corner_diff']] 

for i,k in enumerate(knaboer):
    
    # Initialiser kNN med  k neighbors
    knn = KNeighborsClassifier(n_neighbors = k, p = 2) # p = 2 gir euklidsk avstand

    # Tilpass modellen med treningssettet
    knn.fit(X_tren, df_tren['y'])
    
    # Beregn feilrate på valideringssett
    # score er accuracy = "andel korrekt"
    val_feilrate[i] = 1 - knn.score(X_val, df_val['y'])
    
# Lage plott
plt.title('k-NN for ulike verdier av antall naboer k')
plt.plot(knaboer, val_feilrate, label = 'Feilrate på valideringssettet')
plt.legend()
plt.xlabel('Antall naboer k')
plt.ylabel('Feilrate')
plt.show()

valres=np.vstack((knaboer, val_feilrate))
print("Valideringsfeilrate:")
print(valres.T)
# Out:
# Valideringsfeilrate:
# [[  1.           0.35626536]
#  [  3.           0.35135135]
#  [  5.           0.33169533]
#  [  7.           0.32923833]
#  [  9.           0.32678133]
#  [ 11.           0.32186732]
#  [ 13.           0.33169533]
#  [ 15.           0.32678133]
#  [ 17.           0.31203931]
#  [ 19.           0.32923833]
#  [ 21.           0.31449631]
#  [ 23.           0.32186732]
#  [ 25.           0.31203931]
#  [ 27.           0.3046683 ]
#  [ 29.           0.30958231]
#  [ 31.           0.3046683 ]
#  [ 33.           0.2972973 ]
#  [ 35.           0.3022113 ]
#  [ 37.           0.2997543 ]
#  [ 39.           0.30712531]
#  [ 41.           0.30958231]
#  [ 43.           0.30958231]
#  [ 45.           0.30712531]
#  [ 47.           0.3046683 ]
#  [ 49.           0.3046683 ]
#  [ 51.           0.30712531]
#  [ 53.           0.2972973 ]
#  [ 55.           0.2972973 ]
#  [ 57.           0.2972973 ]
#  [ 59.           0.29484029]
#  [ 61.           0.29484029]
#  [ 63.           0.2972973 ]
#  [ 65.           0.2997543 ]
#  [ 67.           0.2997543 ]
#  [ 69.           0.3022113 ]
#  [ 71.           0.2997543 ]
#  [ 73.           0.2972973 ]
#  [ 75.           0.2997543 ]
#  [ 77.           0.2972973 ]
#  [ 79.           0.3022113 ]
#  [ 81.           0.3022113 ]
#  [ 83.           0.2972973 ]
#  [ 85.           0.29484029]
#  [ 87.           0.29238329]
#  [ 89.           0.29484029]
#  [ 91.           0.28009828]
#  [ 93.           0.29238329]
#  [ 95.           0.2997543 ]
#  [ 97.           0.2972973 ]
#  [ 99.           0.29484029]
#  [101.           0.2972973 ]
#  [103.           0.2972973 ]
#  [105.           0.28746929]
#  [107.           0.28746929]
#  [109.           0.28501229]
#  [111.           0.28255528]
#  [113.           0.28501229]
#  [115.           0.28501229]
#  [117.           0.28501229]
#  [119.           0.29484029]
#  [121.           0.29484029]
#  [123.           0.2972973 ]
#  [125.           0.3022113 ]
#  [127.           0.3022113 ]
#  [129.           0.3022113 ]
#  [131.           0.28992629]
#  [133.           0.28746929]
#  [135.           0.28746929]
#  [137.           0.28992629]
#  [139.           0.27764128]
#  [141.           0.28992629]
#  [143.           0.28501229]
#  [145.           0.28255528]
#  [147.           0.2972973 ]
#  [149.           0.28992629]
#  [151.           0.29484029]
#  [153.           0.28501229]
#  [155.           0.28501229]
#  [157.           0.28992629]
#  [159.           0.2972973 ]
#  [161.           0.2972973 ]
#  [163.           0.29484029]
#  [165.           0.29484029]
#  [167.           0.2997543 ]
#  [169.           0.3022113 ]
#  [171.           0.29484029]
#  [173.           0.2997543 ]
#  [175.           0.29238329]
#  [177.           0.29484029]
#  [179.           0.29484029]
#  [181.           0.28992629]
#  [183.           0.28992629]
#  [185.           0.29484029]
#  [187.           0.29484029]
#  [189.           0.29238329]
#  [191.           0.28255528]
#  [193.           0.2997543 ]
#  [195.           0.30958231]
#  [197.           0.3046683 ]
#  [199.           0.2997543 ]
#  [201.           0.3022113 ]
#  [203.           0.3022113 ]
#  [205.           0.3022113 ]
#  [207.           0.2997543 ]
#  [209.           0.3022113 ]
#  [211.           0.2997543 ]
#  [213.           0.3046683 ]
#  [215.           0.30958231]
#  [217.           0.30712531]
#  [219.           0.2997543 ]
#  [221.           0.2972973 ]
#  [223.           0.3022113 ]
#  [225.           0.3022113 ]
#  [227.           0.3022113 ]
#  [229.           0.3022113 ]
#  [231.           0.2997543 ]
#  [233.           0.29238329]
#  [235.           0.29238329]
#  [237.           0.29238329]
#  [239.           0.28746929]
#  [241.           0.28746929]
#  [243.           0.28746929]
#  [245.           0.29238329]
#  [247.           0.29238329]
#  [249.           0.29238329]]

# %% [markdown]
# **2c.1)** Påstand: kNN kan bare brukes når vi har maksimalt to forklaringsvariabler. Fleip eller fakta?
#
# **2c.2)** Hvilken verdi av $k$ vil du velge? Hvorfor?

# %%
#2c.1
print("Algoritmen fungerer ved å finne de k nærmeste naboene til et gitt punkt i det flerdimensjonale rommet, uavhengig av antall forklaringsvariabler. Det betyr at påstanden er fleip. \n")
    

#2c.2
min_val_feilrate_idx = np.argmin(val_feilrate)
lowest_knaboer = knaboer[min_val_feilrate_idx]  

print("Laveste val_feilrate er:", val_feilrate.min())
print("Den korresponderende knabo er:", lowest_knaboer)
print("Vi velger derfor knabo nr " + str(lowest_knaboer) + ", fordi den har lavest feilrate. \nDette fører til bedre suksess rate for å predikere seier for hjemmelaget")
# Out:
# Algoritmen fungerer ved å finne de k nærmeste naboene til et gitt punkt i det flerdimensjonale rommet, uavhengig av antall forklaringsvariabler. Det betyr at påstanden er fleip.
#
# Laveste val_feilrate er: 0.27764127764127766
# Den korresponderende knabo er: 139
# Vi velger derfor knabo nr 139, fordi den har lavest feilrate.
# Dette fører til bedre suksess rate for å predikere seier for hjemmelaget

# %% [markdown]
# ### Oppgave 2d) Evaluere beste modeller<a name="oppgave2d"></a>
#
# *Oppgave 2d) inneholder 2 spørsmål du skal svare på.*
#
# Nå tar vi frem testsettet og sammenligner den beste modellen for logistisk regresjon med den beste for $k$-nærmeste-nabo-klassifikasjon.
#
# **Gjør nødvendige endringer i koden under.**
#
# **2d.1)** Gjør logistisk regresjon eller $k$-nærmeste-nabo-klassifikasjon det best på fotballkampdataene?
#
# **2d.2)** Drøft klassegrensene (plottet under) for de to beste modellene (én logistisk regresjon og én kNN). Hva forteller klassegrensene deg om problemet? Skriv maksimalt 3 setninger.

# %%
# beste resultat for logistisk regresjon
bestelogist = resultat
test_pred = bestelogist.predict(exog = df_test)
y_testpred = np.where(test_pred > cutoff, 1, 0)
y_testobs = df_test['y']
print("Feilrate logistisk regresjon:", 1 - accuracy_score(y_true = y_testobs, y_pred = y_testpred))

# beste resultat for kNN
bestek = 139
knn = KNeighborsClassifier(n_neighbors = bestek, p = 2)
knn.fit(X_tren, df_tren['y'])
X_test=df_test[['skudd_paa_maal_diff', 'corner_diff']]
print("Feilrate kNN:", 1 - knn.score(X_test, df_test['y']))
# Out:
# Feilrate logistisk regresjon: 0.32843137254901966
# Feilrate kNN: 0.3161764705882353

# %%
# Plotting av klassegrensene for de beste modellene!

# Set the data to be plotted
n = 100  # Step size

# Function to add jitter to data
def jitter(data, factor=0.2):
    # Add random noise to the data
    return data + np.random.uniform(-factor, factor, data.shape)

# Create a grid for plotting
x_min, x_max = X_tren['skudd_paa_maal_diff'].min() - 0.5, X_tren['skudd_paa_maal_diff'].max() + 0.5
y_min, y_max = X_tren['corner_diff'].min() - 0.5, X_tren['corner_diff'].max() + 0.5
xx, yy = np.meshgrid(np.linspace(x_min, x_max, n),
                     np.linspace(y_min, y_max, n))

# Create a temporary DataFrame with feature names
temp_df = pd.DataFrame(np.c_[xx.ravel(), yy.ravel()], columns=['skudd_paa_maal_diff', 'corner_diff'])

# Predict using the KNeighborsClassifier with temporary feature names
Z_knn = knn.predict(temp_df)

# Reshape Z_knn to match the shape of xx
Z_knn = Z_knn.reshape(xx.shape)

# Plot the class boundary for Logistic Regression
beta0 = resultat.params[0]
beta1 = resultat.params['skudd_paa_maal_diff']
beta2 = resultat.params['corner_diff']
x_lr = np.linspace(-3, 5.25, n)
y_lr = -beta0 / beta2 - x_lr * beta1 / beta2

# Create a custom color map for the plot
cmap = mcolors.ListedColormap(['#d8b365', '#5ab4ac'])

# Create a figure and axes
fig, ax = plt.subplots(figsize=(10, 8))

# Plot the decision boundaries
ax.contourf(xx, yy, Z_knn, cmap=cmap, alpha=0.6, levels=1, antialiased=True, linestyles='dashed')
ax.plot(x_lr, y_lr, color = "black", label='Logistic Class Boundary', linewidth=2)

# Scatter plot for the training data
jittered_X_tren = jitter(X_tren[['skudd_paa_maal_diff', 'corner_diff']].values)
scatter = ax.scatter(jittered_X_tren[:, 0], jittered_X_tren[:, 1], c=df_tren['y'], cmap=cmap, s=10)
plt.colorbar(scatter, ax=ax, label='Class')

# Add labels and a title
ax.set_xlabel('Skudd på mål-differanse', fontsize=14)
ax.set_ylabel('Corner-differense', fontsize=14)
ax.set_title('Klassegrense for de beste modellene', fontsize=16)

# Create custom legend elements for Klasse 0 and Klasse 1
legend_elements = [
    mlines.Line2D([], [], marker='s', color='w', markerfacecolor='#d8b365', markersize=10, label='Klasse 0 (KNN)', linestyle='None'),
    mlines.Line2D([], [], marker='s', color='w', markerfacecolor='#5ab4ac', markersize=10, label='Klasse 1 (KNN)', linestyle='None'),
    mlines.Line2D([], [], color='black', lw=2, label='Klassegrense (logistisk regresjon)')
]

# Add legend for class boundaries
ax.legend(handles=legend_elements, title="Klasser", loc='lower right')

# Show the plot
plt.show()
# Out:
# C:\Users\vikto\AppData\Local\Temp\ipykernel_27928\1482554044.py:27: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   beta0 = resultat.params[0]

# %%
#3d.1
print("Vi ser at kNN har lavere feilrate og er dermed bedre")

#3d.2
print("Logistisk regresjon trekker en helt tydlig linje i dataene, hvor det er hjemme seier på den ene siden og tap på den andre siden som en følge av at vi har valgt 0.5 som sannsynlighetsgrense")
print("For kNN plottet ser vi farge plott av 100 x 100 matrisen og skille linjen er her ikke så jevn, og dette kan være en mulig forklarering på høyere treffrate i predikeringen.")
print("Begge metodene predikerer bra og vi ser stort sett samme trend i dataene, og plottet av trenings dataene viser at begge modellene gir et rimelig resultat")
# Out:
# Vi ser at kNN har lavere feilrate og er dermed bedre
# Logistisk regresjon trekker en helt tydlig linje i dataene, hvor det er hjemme seier på den ene siden og tap på den andre siden som en følge av at vi har valgt 0.5 som sannsynlighetsgrense
# For kNN plottet ser vi farge plott av 100 x 100 matrisen og skille linjen er her ikke så jevn, og dette kan være en mulig forklarering på høyere treffrate i predikeringen.
# Begge metodene predikerer bra og vi ser stort sett samme trend i dataene, og plottet av trenings dataene viser at begge modellene gir et rimelig resultat

# %% [markdown]
# [Til toppen.](#top)
